# %%
import numpy as np

# %%
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # VM runs

# %%
### WARNING: files created with python2 must be read with python2
with open ('lossesVM/localemloss', 'rb') as fp:
    em = pickle.load(fp)
with open ('lossesVM/localiemloss', 'rb') as fp:
    iem = pickle.load(fp)
with open ('lossesVM/localoemloss', 'rb') as fp:
    oem = pickle.load(fp)
with open ('lossesVM/localoemvrloss', 'rb') as fp:
    oemvr = pickle.load(fp)

# %%
### WARNING: files created with python2 must be read with python2
with open ('losses/lossesVM_More/localemloss', 'rb') as fp:
    em = pickle.load(fp)
with open ('losses/lossesVM_More/localiemloss', 'rb') as fp:
    oemvr = pickle.load(fp)
with open ('losses/lossesVM_More/localoemloss', 'rb') as fp:
    oem = pickle.load(fp)
with open ('losses/lossesVM_More/localoemvrloss', 'rb') as fp:
    iem = pickle.load(fp)

# %%
### WARNING: files created with python2 must be read with python2
with open ('lossessmall/localemloss', 'rb') as fp:
    em = pickle.load(fp)
with open ('lossessmall/localiemloss', 'rb') as fp:
    iem = pickle.load(fp)
with open ('lossessmall/localoemloss', 'rb') as fp:
    oem = pickle.load(fp)
with open ('lossessmall/localoemvrloss', 'rb') as fp:
    oemvr = pickle.load(fp)

# %%
epochs = len(em)

# %%
epochs
# Out:
# 300

# %%
len(em[30:50])
# Out:
# 20

# %%
start = 45

# %%
start = 280
end = 290
plt.figure(figsize=(20,10))
plt.yscale('log')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in em[start:end]], label='EM')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in iem[start:end]], label='IEM')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in oem[start:end]], label='OEM')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in oemvr[start:end]], label='OEMVR')
leg = plt.legend(fontsize=20,fancybox=True, loc='best')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %%
from decimal import *
getcontext().prec = 25

# %%
map(lambda x,y: x-y,iem[start:end], oem[start:end])
# Out:
# [-3.067954094149172e-05,
#  -3.369542537257075e-05,
#  -3.36278899339959e-05,
#  -3.25753353536129e-05,
#  -3.332916821818799e-05,
#  -1.8618287867866457e-05,
#  -1.7360085621476173e-05,
#  -2.8648923034779727e-05,
#  -2.593363751657307e-05,
#  -2.3981803678907454e-05,
#  -2.422215766273439e-05,
#  -2.4558568838983774e-05,
#  -2.432515611872077e-05,
#  -2.3902844986878335e-05,
#  -2.4125809432007372e-05,
#  -2.4555731215514243e-05,
#  -2.3409549612551928e-05,
#  -2.212474646512419e-05,
#  -1.559924567118287e-05,
#  -1.5207129763439298e-05,
#  -1.475018507335335e-05,
#  -1.354666892439127e-05,
#  -1.337264257017523e-05,
#  -1.2516073184087873e-05,
#  -1.5791505575180054e-05,
#  -1.1469368473626673e-05,
#  -7.376540452241898e-06,
#  -7.6139840530231595e-06,
#  -7.601760444231331e-06,
#  -7.299735443666577e-06,
#  -7.242546416819096e-06,
#  -7.0315145421773195e-06,
#  -6.717426003888249e-06,
#  -6.017173291184008e-06,
#  -5.701251211576164e-06,
#  -5.493609933182597e-06,
# ...

# %%
[element - em[end] for element in iem[start:end]]
[element - em[end] for element in oem[start:end]]
# Out:
# [-0.07896788488142192,
#  -0.07254315106547438,
#  -0.06684240495087579,
#  -0.061763114426867105,
#  -0.05721697489207145,
#  -0.0531422431813553,
#  -0.04944565710320603,
#  -0.04608818463748321,
#  -0.043024658370995894,
#  -0.040216504799900576,
#  -0.037633061947417445,
#  -0.03524892027780879,
#  -0.03304239964927547,
#  -0.030995210181572475,
#  -0.02909210737561807,
#  -0.027319669388816692,
#  -0.02566753202700056,
#  -0.024124824500177056,
#  -0.02268852684937883,
#  -0.021339284401619807,
#  -0.02007611613953486,
#  -0.01889353855221998,
#  -0.017784870200557634,
#  -0.01674568212183658,
#  -0.015770719372085296,
#  -0.014859606730169617,
#  -0.014004528115037829,
#  -0.013198213317082264,
#  -0.012441074577509426,
#  -0.011730227910447866,
#  -0.011062680539907888,
#  -0.010435434072860517,
#  -0.009846018292591907,
#  -0.009292384100263007,
#  -0.00877181172836572,
#  -0.008282311653601937,
#  -0.007822115047019906,
#  -0.007389366539428011,
#  -0.0069839143980061635,
# ...

# %%
start = 280
end = 290
plt.figure(figsize=(20,10))
plt.yscale('log')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in em[start:end]], label='EM')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in iem[start:end]], label='IEM')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in oem[start:end]], label='OEM')
plt.plot(np.arange(len(em[start:end])), [-element+em[end] for element in oemvr[start:end]], label='OEMVR')
leg = plt.legend(fontsize=20,fancybox=True, loc='best')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %%
## start = 0
plt.plot(np.arange(len(em[start:])), em[start:], label='EM')
plt.plot(np.arange(len(em[start:])), iem[start:], label='IEM')
plt.plot(np.arange(len(em[start:])), oem[start:], label='OEM')
plt.plot(np.arange(len(em[start:])), oemvr[start:], label='OEMVR')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %%
start = 190
end = 200
#plt.plot(np.arange(len(em[start:end])), em[start:end], label='EM')
plt.plot(np.arange(len(em[start:end])), iem[start:end], label='IEM')
plt.plot(np.arange(len(em[start:end])), oem[start:end], label='OEM')
plt.plot(np.arange(len(em[start:end])), oemvr[start:end], label='OEMVR')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %% [markdown]
# # LOCAL runs

# %%
with open ('losses/emlossbig', 'rb') as fp:
    em = pickle.load(fp)
with open ('losses/iemlossbig', 'rb') as fp:
    iem = pickle.load(fp)
with open ('losses/oemloss', 'rb') as fp:
    oem = pickle.load(fp)
with open ('losses/oemvrloss', 'rb') as fp:
    oemvr = pickle.load(fp)

# %%
with open ('losses/localemloss', 'rb') as fp:
    em = pickle.load(fp)
with open ('losses/localiemloss', 'rb') as fp:
    iem = pickle.load(fp)

# %%
epochs = len(em)

# %%
localem = list(map(lambda x: x +125052, em))

# %%
localiem = list(map(lambda x: x +125052, iem))

# %%
diff = [a_i - b_i for a_i, b_i in zip(localem, localiem)]

# %%
plt.plot(range(6,10), localem[6:10], label='EM')
plt.plot(range(6,10), localiem[6:10], label='IEM')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %%
plt.plot(np.arange(epochs), localem, label='EM')
plt.plot(np.arange(epochs), localiem, label='IEM')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %% [markdown]
# # With 1000 documents

# %%
with open ('losses/emlossbig', 'rb') as fp:
    em = pickle.load(fp)
with open ('losses/iemlossbig', 'rb') as fp:
    iem = pickle.load(fp)
with open ('losses/oemlossbig', 'rb') as fp:
    oem = pickle.load(fp)
with open ('losses/oemvrlossbig', 'rb') as fp:
    oemvr = pickle.load(fp)

# %%
plt.plot(np.arange(epochs), em, label='EM')
plt.plot(np.arange(epochs), iem, label='IEM')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %%
plt.plot(np.arange(epochs), em, label='EM')
plt.plot(np.arange(epochs), iem, label='IEM')
plt.plot(np.arange(epochs), oem, label='OEM')
plt.plot(np.arange(epochs), oemvr, label='OEMVR')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %% [markdown]
# # With 20 Documents

# %%
plt.plot(np.arange(epochs), em, label='EM')
plt.plot(np.arange(epochs), iem, label='IEM')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()

# %%
plt.plot(np.arange(epochs), em, label='EM')
plt.plot(np.arange(epochs), iem, label='IEM')
plt.plot(np.arange(epochs), oem, label='OEM')
plt.plot(np.arange(epochs), oemvr, label='OEMVR')
leg = plt.legend(fontsize=20,fancybox=True, loc='right')
leg.get_frame().set_alpha(0.5)
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Objective', fontsize=15)
plt.show()
